# %%
from dotenv import load_dotenv
import requests
import os
import pandas as pd
import json
import csv

# %%
load_dotenv()
# Out:
# True

# %%
key = os.getenv("Alpha_vantage_Api_key")
print(type(key))
# Out:
# <class 'NoneType'>

# %%
content_AAPL = requests.get("https://www.alphavantage.co/query?", params={"function":"BALANCE_SHEET","symbol":"AAPL","apikey":"Alpha_vantage_Api_key"})

# %%
df_AAPL = content_AAPL.json()

# %%
dataframe1 = pd.DataFrame.from_dict(df_AAPL["quarterlyReports"][0], orient="index")

# %%
dataframe1
# Out:
#                                             0
# fiscalDateEnding                   2020-06-30
# reportedCurrency                          USD
# totalAssets                      317344000000
# intangibleAssets                         None
# earningAssets                            None
# otherCurrentAssets                10987000000
# totalLiabilities                 245062000000
# totalShareholderEquity            72282000000
# deferredLongTermLiabilities              None
# otherCurrentLiabilities           41318000000
# commonStock                       48696000000
# retainedEarnings                  24136000000
# otherLiabilities                  47606000000
# goodwill                                 None
# otherAssets                       32836000000
# cash                              33383000000
# totalCurrentLiabilities           95318000000
# shortTermDebt                     18675000000
# currentLongTermDebt               18675000000
# ...

# %%
content_GOOGL = requests.get("https://www.alphavantage.co/query?", params={"function":"BALANCE_SHEET","symbol":"GOOGL","apikey":"Alpha_vantage_Api_key"})

# %%
df_GOOGL = content_GOOGL.json()

# %%
dataframe2 = pd.DataFrame.from_dict(df_GOOGL["quarterlyReports"][0], orient="index")

# %%
dataframe2
# Out:
#                                             0
# fiscalDateEnding                   2020-06-30
# reportedCurrency                          USD
# totalAssets                      278492000000
# intangibleAssets                   1697000000
# earningAssets                            None
# otherCurrentAssets                 5579000000
# totalLiabilities                  71170000000
# totalShareholderEquity           207322000000
# deferredLongTermLiabilities        1797000000
# otherCurrentLiabilities            2061000000
# commonStock                       55937000000
# retainedEarnings                 151681000000
# otherLiabilities                  12785000000
# goodwill                          20824000000
# otherAssets                        3626000000
# cash                              17742000000
# totalCurrentLiabilities           43658000000
# shortTermDebt                            None
# currentLongTermDebt                      None
# ...

# %%
content_FB = requests.get("https://www.alphavantage.co/query?", params={"function":"BALANCE_SHEET","symbol":"FB","apikey":"Alpha_vantage_Api_key"})

# %%
df_FB = content_FB.json()

# %%
dataframe3 = pd.DataFrame.from_dict(df_FB["quarterlyReports"][0], orient="index")

# %%
dataframe3
# Out:
#                                             0
# fiscalDateEnding                   2020-06-30
# reportedCurrency                          USD
# totalAssets                      139691000000
# intangibleAssets                    859000000
# earningAssets                            None
# otherCurrentAssets                 2407000000
# totalLiabilities                  29244000000
# totalShareholderEquity           110447000000
# deferredLongTermLiabilities              None
# otherCurrentLiabilities            1163000000
# commonStock                       47805000000
# retainedEarnings                  62784000000
# otherLiabilities                   7879000000
# goodwill                          19029000000
# otherAssets                        3238000000
# cash                              21045000000
# totalCurrentLiabilities           11308000000
# shortTermDebt                            None
# currentLongTermDebt                      None
# ...

# %%
content_AMZN = requests.get("https://www.alphavantage.co/query?", params={"function":"BALANCE_SHEET","symbol":"AMZN","apikey":"Alpha_vantage_Api_key"})

# %%
df_AMZN = content_AMZN.json()

# %%
dataframe4 = pd.DataFrame.from_dict(df_AMZN["quarterlyReports"][0], orient="index")

# %%
dataframe4
# Out:
#                                             0
# fiscalDateEnding                   2020-06-30
# reportedCurrency                          USD
# totalAssets                      258314000000
# intangibleAssets                         None
# earningAssets                            None
# otherCurrentAssets                  354000000
# totalLiabilities                 141788000000
# totalShareholderEquity            73728000000
# deferredLongTermLiabilities              None
# otherCurrentLiabilities            8997000000
# commonStock                           5000000
# retainedEarnings                  38998000000
# otherLiabilities                  14764000000
# goodwill                          14751000000
# otherAssets                       15101000000
# cash                              37466000000
# totalCurrentLiabilities           93896000000
# shortTermDebt                            None
# currentLongTermDebt                      None
# ...

# %%
content_MSFT = requests.get("https://www.alphavantage.co/query?", params={"function":"BALANCE_SHEET","symbol":"MSFT","apikey":"Alpha_vantage_Api_key"})

# %%
df_MSFT = content_MSFT.json()

# %%
dataframe5 = pd.DataFrame.from_dict(df_MSFT["quarterlyReports"][0], orient="index")

# %%
dataframe5
# Out:
#                                             0
# fiscalDateEnding                   2020-06-30
# reportedCurrency                          USD
# totalAssets                      301311000000
# intangibleAssets                   7038000000
# earningAssets                            None
# otherCurrentAssets                11482000000
# totalLiabilities                 183007000000
# totalShareholderEquity           118304000000
# deferredLongTermLiabilities         204000000
# otherCurrentLiabilities           10027000000
# commonStock                       80552000000
# retainedEarnings                  34566000000
# otherLiabilities                  34492000000
# goodwill                          43351000000
# otherAssets                       13138000000
# cash                              13576000000
# totalCurrentLiabilities           72310000000
# shortTermDebt                      3749000000
# currentLongTermDebt                3749000000
# ...
